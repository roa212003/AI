# %% [markdown]
# <a href="https://colab.research.google.com/github/roa212003/AI/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import numpy as np
from pathlib import Path

joints_folder = Path("/content/data_path")
output_folder = Path("processed_data")
output_folder.mkdir(exist_ok=True)

label_dict = {
    "s01_e01": {
        "walk": (252, 390), "sitDown": (572, 686), "standUp": (704, 752),
        "pickUp": (822, 954), "carry": (1016, 1242), "throw": (1434, 1488),
        "push": (1686, 1748), "pull": (1640, 1686), "waveHands": (1834, 2064),
        "clapHands": (2110, 2228)
    },
    "s01_e02": {
        "walk": (154, 192), "sitDown": (530, 628), "standUp": (640, 720),
        "pickUp": (1202, 1356), "carry": (1364, 1520), "throw": (2246, 2294),
        "push": (2752, 2792), "pull": (2820, 2858), "waveHands": (2984, 3204),
        "clapHands": (3250, 3448)
    },
    "s02_e01": {
        "walk": (266, 368), "sitDown": (672, 788), "standUp": (818, 910),
        "pickUp": (1262, 1386), "carry": (1424, 1780), "throw": (2040, 2086),
        "push": (2340, 2376), "pull": (2488, 2550), "waveHands": (2668, 2830),
        "clapHands": (3198, 3324)
    },
    "s02_e02": {
        "walk": (40, 208), "sitDown": (468, 602), "standUp": (620, 722),
        "pickUp": (894, 1038), "carry": (1340, 1480), "throw": (1966, 2014),
        "push": (2194, 2230), "pull": (2314, 2358), "waveHands": (2408, 2630),
        "clapHands": (2690, 2810)
    },
    "s03_e01": {
        "walk": (372, 528), "sitDown": (734, 862), "standUp": (902, 1000),
        "pickUp": (1118, 1284), "carry": (1934, 2168), "throw": (3226, 3282),
        "push": (3556, 3622), "pull": (3660, 3730), "waveHands": (3806, 3960),
        "clapHands": (4076, 4184)
    },
    "s03_e02": {
        "walk": (122, 254), "sitDown": (452, 592), "standUp": (644, 724),
        "pickUp": (848, 1018), "carry": (1078, 1192), "throw": (1638, 1690),
        "push": (1866, 1896), "pull": (1928, 2008), "waveHands": (2054, 2208),
        "clapHands": (2324, 2460)
    },
    "s04_e01": {
        "walk": (348, 496), "sitDown": (788, 864), "standUp": (954, 1056),
        "pickUp": (1190, 1326), "carry": (1580, 1882), "throw": (2306, 2350),
        "push": (2532, 2572), "pull": (2644, 2686), "waveHands": (2790, 2968),
        "clapHands": (3064, 3146)
    },
    "s04_e02": {
        "walk": (420, 546), "sitDown": (1046, 1144), "standUp": (1352, 1414),
        "pickUp": (1682, 1820), "carry": (1868, 2122), "throw": (2564, 2608),
        "push": (2760, 2792), "pull": (2866, 2910), "waveHands": (3070, 3260),
        "clapHands": (3448, 3622)
    },
    "s05_e01": {
        "walk": (708, 888), "sitDown": (1140, 1238), "standUp": (1294, 1394),
        "pickUp": (1482, 1676), "carry": (1736, 2064), "throw": (3104, 3176),
        "push": (3596, 3632), "pull": (3706, 3770), "waveHands": (3946, 4352),
        "clapHands": (4522, 4734)
    },
    "s05_e02": {
        "walk": (212, 376), "sitDown": (634, 756), "standUp": (788, 862),
        "pickUp": (974, 1180), "carry": (1266, 1540), "throw": (1752, 1828),
        "push": (2172, 2230), "pull": (2104, 2156), "waveHands": (2504, 2784),
        "clapHands": (2798, 2900)
    },
    "s06_e01": {
        "walk": (1230, 1366), "sitDown": (1564, 1644), "standUp": (1678, 1758),
        "pickUp": (1862, 1948), "carry": (1966, 2098), "throw": (2392, 2414),
        "push": (2672, 2698), "pull": (2790, 2824), "waveHands": (3046, 3216),
        "clapHands": (3290, 3444)
    },
    "s06_e02": {
        "walk": (294, 426), "sitDown": (710, 818), "standUp": (856, 956),
        "pickUp": (1088, 1174), "carry": (2031, 2202), "throw": (2518, 2562),
        "push": (2702, 2726), "pull": (2770, 2808), "waveHands": (2952, 3060),
        "clapHands": (3096, 3188)
    },
    "s07_e01": {
        "walk": (130, 252), "sitDown": (1038, 1186), "standUp": (1256, 1372),
        "pickUp": (1450, 1602), "carry": (1602, 1758), "throw": (2534, 2614),
        "push": (3290, 3350), "pull": (3350, 3522), "waveHands": (3666, 3902),
        "clapHands": (3990, 4128)
    },
    "s07_e02": {
        "walk": (552, 638), "sitDown": (880, 1014), "standUp": (1014, 1146),
        "pickUp": (1228, 1352), "carry": (1352, 1518), "throw": (1990, 2058),
        "push": (2434, 2496), "pull": (2496, 2618), "waveHands": (2672, 2982),
        "clapHands": (3042, 3152)
    },
    "s08_e01": {
        "walk": (446, 534), "sitDown": (714, 812), "standUp": (836, 900),
        "pickUp": (1026, 1144), "carry": (1228, 1588), "throw": (1880, 1916),
        "push": (2236, 2268), "pull": (2334, 2398), "waveHands": (2598, 2772),
        "clapHands": (2794, 2892)
    },
    "s08_e02": {
        "walk": (138, 246), "sitDown": (610, 716), "standUp": (770, 878),
        "pickUp": (1126, 1200), "carry": (1364, 1650), "throw": (1826, 1878),
        "push": (2030, 2078), "pull": (2126, 2204), "waveHands": (2280, 2506),
        "clapHands": (2574, 2650)
    },
    "s09_e01": {
        "walk": (404, 544), "sitDown": (1080, 1196), "standUp": (1212, 1290),
        "pickUp": (1422, 1538), "carry": (1668, 1970), "throw": (2688, 2728),
        "push": (3266, 3316), "pull": (3316, 3390), "waveHands": (3576, 3762),
        "clapHands": (3992, 4118)
    },
    "s09_e02": {
        "walk": (482, 610), "sitDown": (1026, 1158), "standUp": (1206, 1310),
        "pickUp": (1546, 1678), "carry": (1714, 2120), "throw": (2468, 2522),
        "push": (2696, 2760), "pull": (2770, 2838), "waveHands": (4708, 4872),
        "clapHands": (4904, 4964)
    },
    "s10_e01": {
        "walk": (100, 272), "sitDown": (562, 730), "standUp": (730, 862),
        "pickUp": (924, 1150), "carry": (1394, 1846), "throw": (3304, 3388),
        "push": (3468, 3524), "pull": (3524, 3608), "waveHands": (3962, 4222),
        "clapHands": (4268, 4336)
    },
    "s10_e02": {
        "walk": (96, 220), "sitDown": (500, 658), "standUp": (664, 770),
        "pickUp": (1022, 1232), "carry": (1666, 1720),
        "throw": (1720, 1810), "push": (1944, 1994), "pull": (1982, 2062),
        "waveHands": (2094, 2350), "clapHands": (2454, 2598)
    }
}

def load_joint_file(file_path):
    data = []
    with open(file_path, "r") as f:
        for line in f:
            parts = line.strip().split()
            if not parts: continue
            frame_idx = int(parts[0])
            coords = list(map(float, parts[1:]))
            data.append((frame_idx, coords))
    return data

def process_file(subject_event, labels):
    file_name = f"joints_{subject_event}.txt"
    file_path = joints_folder / file_name
    if not file_path.exists():
        print(f"Missing file: {file_path}")
        return

    full_data = load_joint_file(file_path)

    frame_map = {frame: vec for frame, vec in full_data}

    for action, (start, end) in labels.items():
        frames = []
        for f in range(start, end + 1):
            if f in frame_map:
                frames.append(frame_map[f])

        if len(frames) == 0:
            print(f"No frames found for {subject_event} {action}")
            continue

        action_dir = output_folder / action
        action_dir.mkdir(exist_ok=True)

        npy_name = f"{subject_event}_{start:04d}_{end:04d}.npy"
        np.save(action_dir / npy_name, np.array(frames))

        print(f"Saved: {action}/{npy_name}")

for subject_event, labels in label_dict.items():
    process_file(subject_event, labels)
# Out:
# ✅ Saved: walk/s01_e01_0252_0390.npy
# ✅ Saved: sitDown/s01_e01_0572_0686.npy
# ✅ Saved: standUp/s01_e01_0704_0752.npy
# ✅ Saved: pickUp/s01_e01_0822_0954.npy
# ✅ Saved: carry/s01_e01_1016_1242.npy
# ✅ Saved: throw/s01_e01_1434_1488.npy
# ✅ Saved: push/s01_e01_1686_1748.npy
# ✅ Saved: pull/s01_e01_1640_1686.npy
# ✅ Saved: waveHands/s01_e01_1834_2064.npy
# ✅ Saved: clapHands/s01_e01_2110_2228.npy
# ✅ Saved: walk/s01_e02_0154_0192.npy
# ✅ Saved: sitDown/s01_e02_0530_0628.npy
# ✅ Saved: standUp/s01_e02_0640_0720.npy
# ✅ Saved: pickUp/s01_e02_1202_1356.npy
# ✅ Saved: carry/s01_e02_1364_1520.npy
# ✅ Saved: throw/s01_e02_2246_2294.npy
# ✅ Saved: push/s01_e02_2752_2792.npy
# ✅ Saved: pull/s01_e02_2820_2858.npy
# ✅ Saved: waveHands/s01_e02_2984_3204.npy
# ✅ Saved: clapHands/s01_e02_3250_3448.npy
# ✅ Saved: walk/s02_e01_0266_0368.npy
# ✅ Saved: sitDown/s02_e01_0672_0788.npy
# ✅ Saved: standUp/s02_e01_0818_0910.npy
# ✅ Saved: pickUp/s02_e01_1262_1386.npy
# ✅ Saved: carry/s02_e01_1424_1780.npy
# ✅ Saved: throw/s02_e01_2040_2086.npy
# ✅ Saved: push/s02_e01_2340_2376.npy
# ✅ Saved: pull/s02_e01_2488_2550.npy
# ✅ Saved: waveHands/s02_e01_2668_2830.npy
# ✅ Saved: clapHands/s02_e01_3198_3324.npy
# ✅ Saved: walk/s02_e02_0040_0208.npy
# ✅ Saved: sitDown/s02_e02_0468_0602.npy
# ✅ Saved: standUp/s02_e02_0620_0722.npy
# ✅ Saved: pickUp/s02_e02_0894_1038.npy
# ✅ Saved: carry/s02_e02_1340_1480.npy
# ✅ Saved: throw/s02_e02_1966_2014.npy
# ✅ Saved: push/s02_e02_2194_2230.npy
# ✅ Saved: pull/s02_e02_2314_2358.npy
# ✅ Saved: waveHands/s02_e02_2408_2630.npy
# ✅ Saved: clapHands/s02_e02_2690_2810.npy
# ✅ Saved: walk/s03_e01_0372_0528.npy
# ✅ Saved: sitDown/s03_e01_0734_0862.npy
# ✅ Saved: standUp/s03_e01_0902_1000.npy
# ✅ Saved: pickUp/s03_e01_1118_1284.npy
# ✅ Saved: carry/s03_e01_1934_2168.npy
# ✅ Saved: throw/s03_e01_3226_3282.npy
# ✅ Saved: push/s03_e01_3556_3622.npy
# ✅ Saved: pull/s03_e01_3660_3730.npy
# ✅ Saved: waveHands/s03_e01_3806_3960.npy
# ✅ Saved: clapHands/s03_e01_4076_4184.npy
# ✅ Saved: walk/s03_e02_0122_0254.npy
# ✅ Saved: sitDown/s03_e02_0452_0592.npy
# ✅ Saved: standUp/s03_e02_0644_0724.npy
# ✅ Saved: pickUp/s03_e02_0848_1018.npy
# ✅ Saved: carry/s03_e02_1078_1192.npy
# ✅ Saved: throw/s03_e02_1638_1690.npy
# ✅ Saved: push/s03_e02_1866_1896.npy
# ✅ Saved: pull/s03_e02_1928_2008.npy
# ✅ Saved: waveHands/s03_e02_2054_2208.npy
# ✅ Saved: clapHands/s03_e02_2324_2460.npy
# ✅ Saved: walk/s04_e01_0348_0496.npy
# ✅ Saved: sitDown/s04_e01_0788_0864.npy
# ✅ Saved: standUp/s04_e01_0954_1056.npy
# ✅ Saved: pickUp/s04_e01_1190_1326.npy
# ✅ Saved: carry/s04_e01_1580_1882.npy
# ✅ Saved: throw/s04_e01_2306_2350.npy
# ✅ Saved: push/s04_e01_2532_2572.npy
# ✅ Saved: pull/s04_e01_2644_2686.npy
# ✅ Saved: waveHands/s04_e01_2790_2968.npy
# ✅ Saved: clapHands/s04_e01_3064_3146.npy
# ✅ Saved: walk/s04_e02_0420_0546.npy
# ✅ Saved: sitDown/s04_e02_1046_1144.npy
# ✅ Saved: standUp/s04_e02_1352_1414.npy
# ✅ Saved: pickUp/s04_e02_1682_1820.npy
# ✅ Saved: carry/s04_e02_1868_2122.npy
# ✅ Saved: throw/s04_e02_2564_2608.npy
# ✅ Saved: push/s04_e02_2760_2792.npy
# ✅ Saved: pull/s04_e02_2866_2910.npy
# ✅ Saved: waveHands/s04_e02_3070_3260.npy
# ✅ Saved: clapHands/s04_e02_3448_3622.npy
# ✅ Saved: walk/s05_e01_0708_0888.npy
# ✅ Saved: sitDown/s05_e01_1140_1238.npy
# ✅ Saved: standUp/s05_e01_1294_1394.npy
# ✅ Saved: pickUp/s05_e01_1482_1676.npy
# ✅ Saved: carry/s05_e01_1736_2064.npy
# ✅ Saved: throw/s05_e01_3104_3176.npy
# ✅ Saved: push/s05_e01_3596_3632.npy
# ✅ Saved: pull/s05_e01_3706_3770.npy
# ✅ Saved: waveHands/s05_e01_3946_4352.npy
# ✅ Saved: clapHands/s05_e01_4522_4734.npy
# ✅ Saved: walk/s05_e02_0212_0376.npy
# ✅ Saved: sitDown/s05_e02_0634_0756.npy
# ✅ Saved: standUp/s05_e02_0788_0862.npy
# ✅ Saved: pickUp/s05_e02_0974_1180.npy
# ✅ Saved: carry/s05_e02_1266_1540.npy
# ✅ Saved: throw/s05_e02_1752_1828.npy
# ✅ Saved: push/s05_e02_2172_2230.npy
# ✅ Saved: pull/s05_e02_2104_2156.npy
# ✅ Saved: waveHands/s05_e02_2504_2784.npy
# ✅ Saved: clapHands/s05_e02_2798_2900.npy
# ✅ Saved: walk/s06_e01_1230_1366.npy
# ✅ Saved: sitDown/s06_e01_1564_1644.npy
# ✅ Saved: standUp/s06_e01_1678_1758.npy
# ✅ Saved: pickUp/s06_e01_1862_1948.npy
# ✅ Saved: carry/s06_e01_1966_2098.npy
# ✅ Saved: throw/s06_e01_2392_2414.npy
# ✅ Saved: push/s06_e01_2672_2698.npy
# ✅ Saved: pull/s06_e01_2790_2824.npy
# ✅ Saved: waveHands/s06_e01_3046_3216.npy
# ✅ Saved: clapHands/s06_e01_3290_3444.npy
# ✅ Saved: walk/s06_e02_0294_0426.npy
# ✅ Saved: sitDown/s06_e02_0710_0818.npy
# ✅ Saved: standUp/s06_e02_0856_0956.npy
# ✅ Saved: pickUp/s06_e02_1088_1174.npy
# ✅ Saved: carry/s06_e02_2031_2202.npy
# ✅ Saved: throw/s06_e02_2518_2562.npy
# ✅ Saved: push/s06_e02_2702_2726.npy
# ✅ Saved: pull/s06_e02_2770_2808.npy
# ✅ Saved: waveHands/s06_e02_2952_3060.npy
# ✅ Saved: clapHands/s06_e02_3096_3188.npy
# ✅ Saved: walk/s07_e01_0130_0252.npy
# ✅ Saved: sitDown/s07_e01_1038_1186.npy
# ✅ Saved: standUp/s07_e01_1256_1372.npy
# ✅ Saved: pickUp/s07_e01_1450_1602.npy
# ✅ Saved: carry/s07_e01_1602_1758.npy
# ✅ Saved: throw/s07_e01_2534_2614.npy
# ✅ Saved: push/s07_e01_3290_3350.npy
# ✅ Saved: pull/s07_e01_3350_3522.npy
# ✅ Saved: waveHands/s07_e01_3666_3902.npy
# ✅ Saved: clapHands/s07_e01_3990_4128.npy
# ✅ Saved: walk/s07_e02_0552_0638.npy
# ✅ Saved: sitDown/s07_e02_0880_1014.npy
# ✅ Saved: standUp/s07_e02_1014_1146.npy
# ✅ Saved: pickUp/s07_e02_1228_1352.npy
# ✅ Saved: carry/s07_e02_1352_1518.npy
# ✅ Saved: throw/s07_e02_1990_2058.npy
# ✅ Saved: push/s07_e02_2434_2496.npy
# ✅ Saved: pull/s07_e02_2496_2618.npy
# ✅ Saved: waveHands/s07_e02_2672_2982.npy
# ✅ Saved: clapHands/s07_e02_3042_3152.npy
# ✅ Saved: walk/s08_e01_0446_0534.npy
# ✅ Saved: sitDown/s08_e01_0714_0812.npy
# ✅ Saved: standUp/s08_e01_0836_0900.npy
# ✅ Saved: pickUp/s08_e01_1026_1144.npy
# ✅ Saved: carry/s08_e01_1228_1588.npy
# ✅ Saved: throw/s08_e01_1880_1916.npy
# ✅ Saved: push/s08_e01_2236_2268.npy
# ✅ Saved: pull/s08_e01_2334_2398.npy
# ✅ Saved: waveHands/s08_e01_2598_2772.npy
# ✅ Saved: clapHands/s08_e01_2794_2892.npy
# ✅ Saved: walk/s08_e02_0138_0246.npy
# ✅ Saved: sitDown/s08_e02_0610_0716.npy
# ✅ Saved: standUp/s08_e02_0770_0878.npy
# ✅ Saved: pickUp/s08_e02_1126_1200.npy
# ✅ Saved: carry/s08_e02_1364_1650.npy
# ✅ Saved: throw/s08_e02_1826_1878.npy
# ✅ Saved: push/s08_e02_2030_2078.npy
# ✅ Saved: pull/s08_e02_2126_2204.npy
# ✅ Saved: waveHands/s08_e02_2280_2506.npy
# ✅ Saved: clapHands/s08_e02_2574_2650.npy
# ✅ Saved: walk/s09_e01_0404_0544.npy
# ✅ Saved: sitDown/s09_e01_1080_1196.npy
# ✅ Saved: standUp/s09_e01_1212_1290.npy
# ✅ Saved: pickUp/s09_e01_1422_1538.npy
# ✅ Saved: carry/s09_e01_1668_1970.npy
# ✅ Saved: throw/s09_e01_2688_2728.npy
# ✅ Saved: push/s09_e01_3266_3316.npy
# ✅ Saved: pull/s09_e01_3316_3390.npy
# ✅ Saved: waveHands/s09_e01_3576_3762.npy
# ✅ Saved: clapHands/s09_e01_3992_4118.npy
# ✅ Saved: walk/s09_e02_0482_0610.npy
# ✅ Saved: sitDown/s09_e02_1026_1158.npy
# ✅ Saved: standUp/s09_e02_1206_1310.npy
# ✅ Saved: pickUp/s09_e02_1546_1678.npy
# ✅ Saved: carry/s09_e02_1714_2120.npy
# ✅ Saved: throw/s09_e02_2468_2522.npy
# ✅ Saved: push/s09_e02_2696_2760.npy
# ✅ Saved: pull/s09_e02_2770_2838.npy
# ✅ Saved: waveHands/s09_e02_4708_4872.npy
# ✅ Saved: clapHands/s09_e02_4904_4964.npy
# ✅ Saved: walk/s10_e01_0100_0272.npy
# ✅ Saved: sitDown/s10_e01_0562_0730.npy
# ✅ Saved: standUp/s10_e01_0730_0862.npy
# ✅ Saved: pickUp/s10_e01_0924_1150.npy
# ✅ Saved: carry/s10_e01_1394_1846.npy
# ✅ Saved: throw/s10_e01_3304_3388.npy
# ✅ Saved: push/s10_e01_3468_3524.npy
# ✅ Saved: pull/s10_e01_3524_3608.npy
# ✅ Saved: waveHands/s10_e01_3962_4222.npy
# ✅ Saved: clapHands/s10_e01_4268_4336.npy
# ✅ Saved: walk/s10_e02_0096_0220.npy
# ✅ Saved: sitDown/s10_e02_0500_0658.npy
# ✅ Saved: standUp/s10_e02_0664_0770.npy
# ✅ Saved: pickUp/s10_e02_1022_1232.npy
# ✅ Saved: carry/s10_e02_1666_1720.npy
# ✅ Saved: throw/s10_e02_1720_1810.npy
# ✅ Saved: push/s10_e02_1944_1994.npy
# ✅ Saved: pull/s10_e02_1982_2062.npy
# ✅ Saved: waveHands/s10_e02_2094_2350.npy
# ✅ Saved: clapHands/s10_e02_2454_2598.npy

# %%
import numpy as np
import os
import cv2
from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense

# %%
def preprocess_utkinect_sequences(sequences, target_length=30, num_joints=25):
    processed_seqs = []

    for idx, seq in enumerate(sequences):
        if seq.ndim == 2 and seq.shape[1] == num_joints * 3:
            seq = seq.reshape(seq.shape[0], num_joints, 3)
        elif seq.ndim == 3 and seq.shape[1] == num_joints and seq.shape[2] == 3:
            pass
        else:
            raise ValueError(f"Sequence {idx} có shape không đúng: {seq.shape}")

        # 1. Smoothing
        window_size = 3
        smoothed = np.zeros_like(seq)
        for i in range(seq.shape[0]):
            start = max(0, i - window_size // 2)
            end = min(seq.shape[0], i + window_size // 2 + 1)
            smoothed[i] = np.mean(seq[start:end], axis=0)

        # 2. Normalization:
        normalized = smoothed - smoothed[:, 0:1, :]

        # 3. Resize
        if normalized.shape[0] > target_length:
            indices = np.linspace(0, normalized.shape[0] - 1, target_length).astype(int)
            resized = normalized[indices]
        else:
            pad_len = target_length - normalized.shape[0]
            resized = np.pad(normalized, ((0, pad_len), (0, 0), (0, 0)), mode='constant')

        processed_seqs.append(resized)

    return np.array(processed_seqs)

# %%
# --- Skeleton to RGB Image Encoding ---
def skeleton_to_encoded_image(sequence, normalize=True):
    num_frames, num_joints, _ = sequence.shape
    encoded = np.zeros((num_frames, num_joints, 3))

    if normalize:
        coord_min = sequence.min(axis=(0, 1))
        coord_max = sequence.max(axis=(0, 1))
        coord_range = np.where(coord_max - coord_min < 1e-8, 1, coord_max - coord_min)

        encoded = 255 * (sequence - coord_min) / coord_range
        encoded = np.floor(encoded).astype(np.uint8)
    else:
        encoded = sequence.copy()

    return encoded

# %%
# --- CNN Model Definition ---
def build_baseline_cnn(input_shape, num_classes=10):
    model = Sequential([
        Conv2D(32, (3, 3), activation='relu', padding='same', input_shape=input_shape),
        MaxPooling2D((2, 2)),

        Conv2D(64, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),

        Conv2D(128, (3, 3), activation='relu', padding='same'),
        MaxPooling2D((2, 2)),

        Flatten(),
        Dense(256, activation='relu'),
        Dense(128, activation='relu'),
        Dense(num_classes, activation='softmax')
    ])

    model.compile(optimizer='adam',
                  loss='sparse_categorical_crossentropy',
                  metrics=['accuracy'])
    return model

# %%
def main():
    action_names = ["walk", "sitDown", "standUp", "pickUp", "carry", "throw", "push", "pull", "waveHands", "clapHands"]
    action_to_idx = {action: idx for idx, action in enumerate(action_names)}


    all_data = []
    all_labels = []

    for action in action_names:
        action_dir = output_folder / action
        if not action_dir.exists():
            continue
        for npy_file in action_dir.glob("*.npy"):
            seq = np.load(npy_file)
            all_data.append(seq)
            all_labels.append(action_to_idx[action])

    # Tiền xử lý để smoothing, normalize và resize tất cả chuỗi
    processed_data = preprocess_utkinect_sequences(all_data, target_length=30)

    # Chuyển sang numpy array sau khi đã đồng nhất shape
    processed_data = np.array(processed_data)
    all_labels = np.array(all_labels)

    print("Processed data shape:", processed_data.shape)
    print("Labels shape:", all_labels.shape)

if __name__ == "__main__":
    main()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-20-0bc64deb9a80> in <cell line: 0>()
#      27
#      28 if __name__ == "__main__":
# ---> 29     main()
#
# <ipython-input-20-0bc64deb9a80> in main()
#      17
#      18     # Tiền xử lý để smoothing, normalize và resize tất cả chuỗi
# ---> 19     processed_data = preprocess_utkinect_sequences(all_data, target_length=30)
#      20
#      21     # Chuyển sang numpy array sau khi đã đồng nhất shape
#
# <ipython-input-19-7f421432531f> in preprocess_utkinect_sequences(sequences, target_length, num_joints)
#      10             pass
#      11         else:
# ---> 12             raise ValueError(f"Sequence {idx} có shape không đúng: {seq.shape}")
#      13
#      14         # 1. Smoothing (moving average window size=3)
#
# ValueError: Sequence 0 có shape không đúng: (50, 60)
